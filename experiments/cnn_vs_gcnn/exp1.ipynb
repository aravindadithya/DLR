# %%
import os
model_dir1= os.path.join('/work/DLR','trained_models', 'MNIST', 'model4', 'nn_models/')
model_dir2= os.path.join('/work/DLR','trained_models', 'MNIST', 'model5', 'nn_models/')

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from utils import trainer as tr
from torch.utils.data import Dataset
import random
import torch.backends.cudnn as cudnn
import numpy as np
from trained_models.MNIST.model4 import trainer as t1
from trained_models.MNIST.model5 import trainer as t2
import numpy as np
from sklearn.model_selection import train_test_split
from torch.linalg import norm
from torchvision import models
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from copy import deepcopy
from torch.nn.functional import pad
from torch.func import jacrev

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
#device='cpu'
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %%
# !nvidia-sml
# Out:
# /usr/bin/sh: 1: nvidia-sml: not found

# %%
torch.cuda.empty_cache()

# %%
trainloader1, valloader1, testloader1 = t1.get_loaders()
net1= t1.get_untrained_net()
import os
if os.path.exists(model_dir1+'mnist_gcnn_trained_nn.pth'):
    checkpoint = torch.load(model_dir1+'mnist_gcnn_trained_nn.pth', map_location=torch.device(device), weights_only=True)
    net1.load_state_dict(checkpoint['state_dict'])  # Access the 'state_dict' within the loaded dictionary
    print("Model weights loaded successfully.")
#t1.train_net()
# Out:
# Model weights loaded successfully.

# %%
trainloader2, valloader2, testloader2 = t2.get_loaders()
net2= t2.get_untrained_net()
import os
if os.path.exists(model_dir2+'mnist_conv_trained_nn.pth'):
    checkpoint = torch.load(model_dir2+'mnist_conv_trained_nn.pth', map_location=torch.device(device), weights_only=True)
    net2.load_state_dict(checkpoint['state_dict'])  # Access the 'state_dict' within the loaded dictionary
    print("Model weights loaded successfully.")
t2.train_net()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       6     net2.load_state_dict(checkpoint['state_dict'])  # Access the 'state_dict' within the loaded dictionary
#       7     print("Model weights loaded successfully.")
# ----> 8 t2.train_net()
#
# File /work/DLR/trained_models/MNIST/model5/trainer.py:52, in train_net()
#      50 net = get_untrained_net()
#      51 trainloader, valloader, testloader = get_loaders()
# ---> 52 if os.path.exists(model_dir+'mnist_conv_trained_nn.pth'):
#      53     checkpoint = torch.load(model_dir+'mnist_conv_trained_nn.pth', map_location=torch.device(device))
#      54     net.load_state_dict(checkpoint['state_dict'])  # Access the 'state_dict' within the loaded dictionary
#
# NameError: name 'model_dir' is not defined

# %%
print(tr.get_acc_ce(net1.to(device), testloader1))
# Out:
# /work/DLR/trained_models/MNIST/model4/model4.py:49: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# 99.18

# %%
print(tr.get_acc_ce(net2.to(device), testloader2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(tr.get_acc_ce(net2.to(device), testloader2))
#
# NameError: name 'net2' is not defined
