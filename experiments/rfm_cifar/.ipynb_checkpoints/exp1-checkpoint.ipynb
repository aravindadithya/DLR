# %%
import torch
import torchvision
import torchvision.transforms as transforms
from utils import agop_gcnn as agc
from utils import trainer as tr
from torch.utils.data import Dataset
import random
import torch.backends.cudnn as cudnn
#import rfm
import numpy as np
from trained_models.CIFAR.model2 import trainer as t
import numpy as np
from sklearn.model_selection import train_test_split
from torch.linalg import norm
from torchvision import models
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from utils.groupy.gconv.pytorch_gconv.splitgconv2d import P4ConvZ2, P4ConvP4, P4MConvZ2, P4MConvP4M
from groupy.gconv.make_gconv_indices import *
from copy import deepcopy
from torch.nn.functional import pad
from torch.func import jacrev
# Out:
# Setting up a new session...
# Without the incoming socket you cannot receive events from the server or register event handlers to your Visdom client.

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
#device='cpu'
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %%
# !nvidia-smi
# Out:
# Mon Sep  8 07:43:41 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.124.04             Driver Version: 570.124.04     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090        On  |   00000000:05:00.0 Off |                  Off |
# |  0%   42C    P8             18W /  450W |       4MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
torch.cuda.empty_cache()

# %%
trainloader, valloader, testloader, init_net, net = t.train_net(force_train=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Model weights loaded successfully.

# %%
#tr.visualize_predictions(net, testloader, range(10), device, num_images=36)
print(tr.get_acc_ce(net.to(device), testloader))
# Out:
# 89.05

# %%
'''alpha:0.5 0.67
         0.25 0.7630
'''
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=0, max_batches=30, alpha=0.25)
# Out:
# l_idx 0
# Computing GOP for sample 0 out of 30
# Computing GOP for sample 1 out of 30
# Computing GOP for sample 2 out of 30
# Computing GOP for sample 3 out of 30
# Computing GOP for sample 4 out of 30
# Computing GOP for sample 5 out of 30
# Computing GOP for sample 6 out of 30
# Computing GOP for sample 7 out of 30
# Computing GOP for sample 8 out of 30
# Computing GOP for sample 9 out of 30
# Computing GOP for sample 10 out of 30
# Computing GOP for sample 11 out of 30
# Computing GOP for sample 12 out of 30
# Computing GOP for sample 13 out of 30
# Computing GOP for sample 14 out of 30
# Computing GOP for sample 15 out of 30
# Computing GOP for sample 16 out of 30
# Computing GOP for sample 17 out of 30
# Computing GOP for sample 18 out of 30
# Computing GOP for sample 19 out of 30
# Computing GOP for sample 20 out of 30
# Computing GOP for sample 21 out of 30
# Computing GOP for sample 22 out of 30
# Computing GOP for sample 23 out of 30
# Computing GOP for sample 24 out of 30
# ...

# %%
d= agc.verify_NFA(net, init_net, trainloader, layer_idx=1,max_batches=10, alpha=0.5)
# Out:
# l_idx 3
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([1656, 1656])
# Correlation between Initial and Trained CNFM:  tensor(0.0141, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0190, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.8923, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=2, max_batches=10, alpha= 0.76)
# Out:
# l_idx 4
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([1656, 1656])
# Correlation between Initial and Trained CNFM:  tensor(0.0153, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0216, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.6766, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=3, max_batches=10)
# Out:
# l_idx 5
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([1656, 1656])
# Correlation between Initial and Trained CNFM:  tensor(0.0202, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0193, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9044, device='cuda:0', grad_fn=<DivBackward0>)
# tensor([[ 0.0085,  0.0049,  0.0051,  ...,  0.0016, -0.0006,  0.0019],
#         [ 0.0109,  0.0153,  0.0094,  ...,  0.0019, -0.0019,  0.0030],
# ...

# %%
agc.verify_NFA(net, init_net, trainloader, layer_idx=4, max_batches=10)
# Out:
# l_idx 6
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([1656, 1656])
# Correlation between Initial and Trained CNFM:  tensor(0.0430, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0520, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9446, device='cuda:0', grad_fn=<DivBackward0>)
# tensor([[2.7254e-03, 1.8548e-03, 1.1986e-03,  ..., 2.0643e-04, 1.0479e-03,
#          1.3902e-03],
#         [1.5546e-03, 1.0969e-03, 1.2655e-03,  ..., 9.2472e-04, 1.0952e-03,
# ...

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=5, max_batches=10)
# Out:
# l_idx 7
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([3240, 3240])
# Correlation between Initial and Trained CNFM:  tensor(0.0122, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0137, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9446, device='cuda:0', grad_fn=<DivBackward0>)
# tensor([[ 3.9763e-03,  2.3287e-03,  9.8365e-04,  ...,  4.8979e-04,
#          -5.2403e-06,  1.4579e-04],
#         [ 2.2689e-03,  2.6656e-03,  1.1901e-03,  ...,  5.1787e-04,
# ...

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=6, max_batches=10)
# Out:
# l_idx 8
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([3240, 3240])
# Correlation between Initial and Trained CNFM:  tensor(0.0191, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0200, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.8924, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=7, max_batches=10)
# Out:
# l_idx 9
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([3240, 3240])
# Correlation between Initial and Trained CNFM:  tensor(0.0219, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0261, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9246, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=8, max_batches=10)
# Out:
# l_idx 10
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([3240, 3240])
# Correlation between Initial and Trained CNFM:  tensor(0.0555, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0632, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9455, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=9, max_batches=10)
# Out:
# l_idx 11
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([6552, 6552])
# Correlation between Initial and Trained CNFM:  tensor(0.0286, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0354, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9327, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=10, max_batches=10)
# Out:
# l_idx 12
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([6552, 6552])
# Correlation between Initial and Trained CNFM:  tensor(0.0294, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0346, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9517, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=11, max_batches=10)
# Out:
# l_idx 13
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([6552, 6552])
# Correlation between Initial and Trained CNFM:  tensor(0.0342, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0412, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9301, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=12, max_batches=10)
# Out:
# l_idx 14
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([6552, 6552])
# Correlation between Initial and Trained CNFM:  tensor(0.0267, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0276, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9330, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=13, max_batches=10)
# Out:
# l_idx 15
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([6552, 6552])
# Correlation between Initial and Trained CNFM:  tensor(0.0219, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0269, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9121, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=14, max_batches=10)
# Out:
# l_idx 16
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([6552, 6552])
# Correlation between Initial and Trained CNFM:  tensor(0.0641, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0796, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.9411, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=15, max_batches=10)
# Out:
# l_idx 17
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([13032, 13032])
# Correlation between Initial and Trained CNFM:  tensor(0.0490, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0605, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.8770, device='cuda:0', grad_fn=<DivBackward0>)

# %%
d=agc.verify_NFA(net, init_net, trainloader, layer_idx=16, max_batches=10)
# Out:
# l_idx 18
# Computing GOP for sample 0 out of 10
# Computing GOP for sample 1 out of 10
# Computing GOP for sample 2 out of 10
# Computing GOP for sample 3 out of 10
# Computing GOP for sample 4 out of 10
# Computing GOP for sample 5 out of 10
# Computing GOP for sample 6 out of 10
# Computing GOP for sample 7 out of 10
# Computing GOP for sample 8 out of 10
# Computing GOP for sample 9 out of 10
# Computing GOP for sample 10 out of 10
# Shape after gradients:  torch.Size([13032, 13032])
# Correlation between Initial and Trained CNFM:  tensor(0.0158, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Initial CNFM and Trained AGOP:  tensor(0.0183, device='cuda:0', grad_fn=<DivBackward0>)
# Correlation between Trained CNFM and Trained AGOP:  tensor(0.8427, device='cuda:0', grad_fn=<DivBackward0>)

# %%
verify_NFA(net, init_net, trainloader, layer_idx=2)
# Out:
# l_idx 4
# Computing GOP for sample 0 out of 2
# yo torch.Size([128, 2, 32, 32, 184, 3, 3])
# torch.Size([1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 32, 32, 184, 3, 3])
# torch.Size([1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 32, 32, 184, 3, 3])
# torch.Size([1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 32, 32, 184, 3, 3])
# torch.Size([1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 32, 32, 184, 3, 3])
# torch.Size([1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 32, 32, 184, 3, 3])
# torch.Size([1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 32, 32, 184, 3, 3])
# torch.Size([1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 2, 32, 32, 184, 3, 3])
# torch.Size([128, 1, 32, 32, 184, 3, 3])
# ...

# %% [markdown]
# ## Alpha vs Agop

# %%
import torch
import matplotlib.pyplot as plt

X= torch.load("corr_data_layer0_centering.pt", weights_only=True)
x_coords =[]
y_coords = []
for i in range(len(X)):
    x_coords.append(X[i][0])
    y_coords.append(X[i][1].cpu().detach().numpy())


# 3. Create the plot
plt.figure(figsize=(8, 6))

# Plot the points as a scatter plot
plt.scatter(x_coords, y_coords, color='cornflowerblue', marker='o', s=100, label='Data Points')

# Plot the line connecting the points
#plt.plot(x_coords, y_coords, color='darkorange', linestyle='-', linewidth=2, label='Connecting Line')

# 4. Add labels, title, and grid for better readability
plt.title('With centering', fontsize=16)
plt.xlabel('Alpha', fontsize=12)
plt.ylabel('Correlation', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# 5. Display the graph
plt.show()

# %%
X= torch.load("corr_data_layer0_nocentering.pt", weights_only=True)
x_coords =[]
y_coords = []
for i in range(len(X)):
    x_coords.append(X[i][0])
    y_coords.append(X[i][1].cpu().detach().numpy())


# 3. Create the plot
plt.figure(figsize=(8, 6))

# Plot the points as a scatter plot
plt.scatter(x_coords, y_coords, color='cornflowerblue', marker='o', s=100, label='Data Points')

# Plot the line connecting the points
#plt.plot(x_coords, y_coords, color='darkorange', linestyle='-', linewidth=2, label='Connecting Line')

# 4. Add labels, title, and grid for better readability
plt.title('Without centering', fontsize=16)
plt.xlabel('Alpha', fontsize=12)
plt.ylabel('Correlation', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# 5. Display the graph
plt.show()
